# %% [markdown]
# 16\11\2023

# %% [markdown]
# datavisualization **bar chart**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips_df=sns.load_dataset("tips")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df['tip'].mean()
# Out:
# 2.99827868852459

# %%
tips_df['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
bill_avg_data=tips_df.groupby('day')[['total_bill']].mean()
bill_avg_data
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg_data.index,bill_avg_data.total_bill);

# %%
sns.barplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='time',y='total_bill',hue='sex',data=tips_df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='smoker',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# heatmap

# %%
flights_df=sns.load_dataset('flights')

# %%
flights_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(x='year',y='passengers',data=flights_df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.barplot(x='month',y='passengers',data=flights_df)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.barplot(x='year',y='passengers',hue='month',data=flights_df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# for heatmap first create a matrix using pivot

# %%
flight=flights_df.pivot('month','year','passengers')
# Out:
# <ipython-input-42-48b54b2abaa1>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flight=flights_df.pivot('month','year','passengers')

# %%
flight
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title('no of passengers(1000s)')
sns.heatmap(flight);

# %%
plt.title('no of passengers(1000s)')
sns.heatmap(flight,fmt="d",annot=True,cmap='Blues');

# %% [markdown]
# display images in matplotlib

# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://i.imgur.com/SkPbq.jpg','chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x79e6b1883190>)

# %%
#before displaying an image it has to be read into memory using PIL module

# %%
from PIL import Image

# %%
img=Image.open('chart.jpg')

# %% [markdown]
# the image loaded using PIL is a 3-d numpy array containing pixel intensities of red, green and blues

# %%
img_array=np.array(img)

# %%
img_array.shape
# Out:
# (481, 640, 3)

# %%
plt.imshow(img);

# %% [markdown]
# #we can turn off the axes and grid lines

# %%
plt.grid(False)
plt.title(' a data science meme')
plt.axis('off')
plt.imshow(img);
# plt.border('off')

# %%
plt.grid(False)
plt.title(' a data science meme')
plt.axis('off')
plt.imshow(img_array[125:450,105:305]);

# %% [markdown]
# #plotting multiple charts in a grid

# %%
fig,axes=plt.subplots(2,3)#(no. of rows,cols)
plt.tight_layout(pad=2) #add spacing
# Out:
# (array([<Axes: >, <Axes: >, <Axes: >], dtype=object),
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
iris_df=sns.load_dataset('iris')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig,axes=plt.subplots(2,2)
axes[0,0].plot(iris_df['species'],iris_df['petal_width'])
axes[0,0].set_title('species vs petal_width')
axes[0,0].legend(['species','petal-width'])

sns.scatterplot(x=iris_df['petal_length'],y=iris_df['petal_width'],hue=iris_df['species'],ax=axes[1,0])
axes[1,0].set_title('petal_length vs petal_width')
# axes[1,0].legend(['species','petal-width'])
plt.tight_layout(pad=1.5)

virginica_df = iris_df[iris_df['species'] == 'virginica']
setosa_df = iris_df[iris_df['species'] == 'setosa']
# Create separate histograms for 'sepal_length'
axes[0, 1].hist(setosa_df['sepal_length'], bins=10, color='blue', alpha=0.7, label='Setosa')
axes[0, 1].hist(virginica_df['sepal_length'], bins=10, color='red', alpha=0.7, label='Virginica')

axes[0, 1].set_title('Sepal Length Distribution')
axes[0, 1].legend()

# Add other subplot settings as needed

plt.tight_layout(pad=1.5)  # Add spacing
plt.show()


axes[1,1].set_title('flight traffic')
sns.heatmap(flight,ax=axes[1,1])
# Out:
# <Axes: title={'center': 'flight traffic'}, xlabel='year', ylabel='month'>

# %% [markdown]
# #box plot

# %% [markdown]
# A box plot shows the distribution of data along a single axis, using a "box" and "whiskers". The lower end of the box represents the 1st quartile (i.e. 25% of values are below it), and the upper end of the box represents the 3rd quartile (i.e. 25% of values are above it). The median value is represented via a line inside the box. The "whiskers" represent the minimum & maximum values (sometimes excluding outliers, which are represented as dots).

# %%
tips = sns.load_dataset("tips");
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Chart title
plt.title("Daily Total Bill")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x=tips['day'], y=tips['total_bill'], hue=tips['smoker'])
# Out:
# <Axes: title={'center': 'Daily Total Bill'}, xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", hue="smoker", data=tips);
